# %%
import pandas
import sqlalchemy
# !pip install ipython-sql
# %load_ext sql

# %%
# %sql ibm_db_sa://qqm47080:p9sgk4517fgbr%2Bk1@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB

# %%
# %sql SELECT * FROM syscat.tables\
where tabschema='QQM47080'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('QQM47080', 'COUNTRYS', 'QQM47080', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2020, 6, 24, 8, 59, 49, 965645), datetime.datetime(2020, 6, 24, 8, 59, 50, 158274), datetime.datetime(2020, 6, 24, 8, 59, 50, 158281), datetime.datetime(2020, 6, 24, 9, 12, 40, 940824), 3, 6, 862, 0, 0, 0, 1, -1, -1, -1, 0, 'qqm47080space1', None, None, 0, 0, 0, 1, 1, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 0, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2020, 6, 24, 8, 59, 49, 965645), 0, ' ', None, None, 'N', 'QQM47080', ' ', ' ', ' ', datetime.date(2020, 6, 30), ' ', 'N', 'R', 'N', -1.0, None),
# ...

# %%
# %sql SELECT * FROM syscat.COLUMNS \
where tabname='SCHOOLS'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('QQM47080', 'SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', -1, '\x00\x00\x00\x00', '\x00\x00\x00\x00', -1, None, 0, -1, -1, -1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql SELECT colname,typename,length FROM syscat.columns \
where tabname='SCHOOLS'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('School_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 65),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Street_Address', 'VARCHAR', 30),
#  ('City', 'VARCHAR', 7),
#  ('State', 'VARCHAR', 2),
#  ('ZIP_Code', 'INTEGER', 4),
#  ('Phone_Number', 'VARCHAR', 14),
#  ('Link', 'VARCHAR', 78),
#  ('Network_Manager', 'VARCHAR', 40),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Track_Schedule', 'VARCHAR', 12),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('Safety_Icon', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('Family_Involvement_Icon', 'VARCHAR', 11),
#  ('Family_Involvement_Score', 'VARCHAR', 3),
#  ('Environment_Icon', 'VARCHAR', 11),
#  ('Environment_Score', 'SMALLINT', 2),
# ...

# %%
# %sql SELECT DISTINCT(typename) FROM syscat.columns \
where tabname='SCHOOLS'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('DECIMAL',), ('INTEGER',), ('SMALLINT',), ('VARCHAR',)]

# %%
# %sql SELECT * from SCHOOLS  LIMIT 5
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql select count(*) as "Number_of_ES" FROM SCHOOLS \
WHERE "Elementary, Middle, or High School"= 'ES'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('462'),)]

# %%
# %sql select MAX(safety_score) as "maximum score" FROM SCHOOLS
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(99,)]

# %%
# %sql select * from SCHOOLS \
WHERE safety_score =(select MAX(safety_score) FROM SCHOOLS) limit 2
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql select name_of_school,"Elementary, Middle, or High School",  average_student_attendance from SCHOOLS \
ORDER BY average_student_attendance  DESC NULLS LAST LIMIT 10
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('John Charles Haines Elementary School', 'ES', '98.40%'),
#  ('James Ward Elementary School', 'ES', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', 'ES', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', 'ES', '97.60%'),
#  ('Rachel Carson Elementary School', 'ES', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', 'ES', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', 'ES', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', 'ES', '97.40%'),
#  ('Disney II Magnet School', 'ES', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', 'ES', '97.20%')]

# %%
# %sql select name_of_school,"Elementary, Middle, or High School",  average_student_attendance from SCHOOLS \
ORDER BY average_student_attendance FETCH FIRST 5 ROWS ONLY
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', 'HS', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', 'ES', '60.90%'),
#  ('Dyett High School', 'HS', '62.50%'),
#  ('Wendell Phillips Academy High School', 'HS', '63.00%'),
#  ('Orr Academy High School', 'HS', '66.30%')]

# %%
# %sql SELECT name_of_school, "Elementary, Middle, or High School" , REPLACE(average_student_attendance, '%', '') from SCHOOLS \
ORDER BY average_student_attendance LIMIT 5
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', 'HS', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', 'ES', '60.90'),
#  ('Dyett High School', 'HS', '62.50'),
#  ('Wendell Phillips Academy High School', 'HS', '63.00'),
#  ('Orr Academy High School', 'HS', '66.30')]

# %%
# %sql SELECT name_of_school, "Elementary, Middle, or High School" , REPLACE(average_student_attendance, '%', '') from SCHOOLS \
WHERE average_student_attendance < '70.00'
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Barbara Vick Early Childhood & Family Center', 'ES', '60.90'),
#  ('Chicago Vocational Career Academy High School', 'HS', '68.80'),
#  ('Dyett High School', 'HS', '62.50'),
#  ('Manley Career Academy High School', 'HS', '66.80'),
#  ('Orr Academy High School', 'HS', '66.30'),
#  ('Richard T Crane Technical Preparatory High School', 'HS', '57.90'),
#  ('Roberto Clemente Community Academy High School', 'HS', '69.60'),
#  ('Wendell Phillips Academy High School', 'HS', '63.00')]

# %%
# %sql select * from SCHOOLS \
WHERE safety_score =(select MAX(safety_score) FROM SCHOOLS) limit 2
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql SELECT community_area_name, sum(college_enrollment) as "total" FROM SCHOOLS \
GROUP BY community_area_name \
ORDER BY "total" asc limit 5
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# %sql SELECT * FROM chicagodata limit 5
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)]

# %%
# %sql SELECT * FROM SCHOOLS  LIMIT 5
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql SELECT C.hardship_index ,S.community_area_number, C.ca , S.college_enrollment FROM SCHOOLS AS S,CHICAGODATA AS C \
where S.community_area_number=C.ca AND s.college_enrollment  = 4368
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(6.0, 5, 5.0, 4368)]

# %%
# %sql select hardship_index from chicagodata CD, schools CPS \
   where CD.ca IN  (SELECT community_area_number  FROM SCHOOLS ORDER BY college_enrollment DESC LIMIT 5 )
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
#  (6.0,),
# ...

# %%
# %sql SELECT C.hardship_index ,S.community_area_number, C.ca , S.college_enrollment FROM SCHOOLS AS S,CHICAGODATA AS C \
where C.ca  IN (SELECT community_area_number  FROM SCHOOLS ORDER BY college_enrollment DESC LIMIT 1 )
# Out:
#  * ibm_db_sa://qqm47080:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(6.0, 7, 5.0, 813),
#  (6.0, 43, 5.0, 521),
#  (6.0, 70, 5.0, 1324),
#  (6.0, 61, 5.0, 556),
#  (6.0, 34, 5.0, 302),
#  (6.0, 14, 5.0, 266),
#  (6.0, 5, 5.0, 4368),
#  (6.0, 24, 5.0, 620),
#  (6.0, 5, 5.0, 232),
#  (6.0, 14, 5.0, 1023),
#  (6.0, 5, 5.0, 998),
#  (6.0, 61, 5.0, 476),
#  (6.0, 6, 5.0, 307),
#  (6.0, 24, 5.0, 398),
#  (6.0, 49, 5.0, 525),
#  (6.0, 49, 5.0, 428),
#  (6.0, 23, 5.0, 801),
#  (6.0, 72, 5.0, 274),
#  (6.0, 27, 5.0, 551),
#  (6.0, 29, 5.0, 171),
#  (6.0, 48, 5.0, 264),
#  (6.0, 22, 5.0, 586),
#  (6.0, 68, 5.0, 539),
#  (6.0, 24, 5.0, 114),
#  (6.0, 42, 5.0, 730),
#  (6.0, 28, 5.0, 556),
#  (6.0, 67, 5.0, 339),
#  (6.0, 74, 5.0, 245),
#  (6.0, 24, 5.0, 669),
#  (6.0, 38, 5.0, 436),
#  (6.0, 39, 5.0, 550),
#  (6.0, 67, 5.0, 345),
#  (6.0, 46, 5.0, 905),
#  (6.0, 61, 5.0, 539),
#  (6.0, 44, 5.0, 652),
#  (6.0, 17, 5.0, 784),
#  (6.0, 44, 5.0, 459),
# ...
